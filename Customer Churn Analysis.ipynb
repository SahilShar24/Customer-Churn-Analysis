# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import matplotlib.ticker as mtick

# %%
df = pd.read_csv("C:/Users/ASUS/Desktop/Sahil python/CustomerChurn.csv")

# %%
df.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df['Churn'].value_counts().plot(kind = 'barh',figsize =(7,5))
plt.xlabel("Count", labelpad = 10)
plt.ylabel("Target variable", labelpad = 10)
plt.title("Count of Target per category", y= 1.02)
# Out:
# Text(0.5, 1.02, 'Count of Target per category')

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df['Churn'].value_counts()/len(df)*100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: count, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# Data Cleaning

# %%
new_df = df.copy()

# %%
new_df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
new_df.TotalCharges = pd.to_numeric(new_df.TotalCharges, errors = 'coerce')
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
new_df.dropna(how = 'any', inplace = True)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7032 non-null   object
#  1   gender            7032 non-null   object
#  2   SeniorCitizen     7032 non-null   int64
#  3   Partner           7032 non-null   object
#  4   Dependents        7032 non-null   object
#  5   tenure            7032 non-null   int64
#  6   PhoneService      7032 non-null   object
#  7   MultipleLines     7032 non-null   object
#  8   InternetService   7032 non-null   object
#  9   OnlineSecurity    7032 non-null   object
#  10  OnlineBackup      7032 non-null   object
#  11  DeviceProtection  7032 non-null   object
#  12  TechSupport       7032 non-null   object
#  13  StreamingTV       7032 non-null   object
#  14  StreamingMovies   7032 non-null   object
#  15  Contract          7032 non-null   object
# ...

# %% [markdown]
# After Cleaning process i directly jumped into removing unwanted column and further analysis using graphs but i came up across
# tenure graph it does'nt giving me the accurate data so that, i come back and created bins on tenure for better graph visuals

# %%
print(new_df['tenure'].max())
# Out:
# 72

# %%
labels = ["{0} - {1}". format(i, i + 11) for i in range(1,72,12)]
new_df['Tenure_group'] = pd.cut(new_df.tenure, range(1,80,12), right = False, labels = labels)

# %%
new_df['Tenure_group'].value_counts()
# Out:
# Tenure_group
# 1 - 12     2175
# 61 - 72    1407
# 13 - 24    1024
# 25 - 36     832
# 49 - 60     832
# 37 - 48     762
# Name: count, dtype: int64

# %%
new_df.drop(columns = ['customerID','tenure'], axis = 1, inplace = True)

# %%
new_df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %% [markdown]
# Data Exploration

# %% [markdown]
# Univariate Analysis

# %%
for i, predictor in enumerate(new_df.drop(columns=['Churn','TotalCharges','MonthlyCharges','PaymentMethod'])):
    plt.figure(i)
    sns.countplot(data = new_df, x = predictor, hue = 'Churn')

# %%
plt.figure(figsize = (6,4))
ax = sns.countplot(x = 'PaymentMethod', data = df, hue = 'Churn')
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
plt.title("Churned Customers By payment Method")
plt.xticks(rotation = 45)
plt.show()

# %%
new_df.groupby('MultipleLines')['Churn'].value_counts()
# Out:
# MultipleLines     Churn
# No                No       2536
#                   Yes       849
# No phone service  No        510
#                   Yes       170
# Yes               No       2117
#                   Yes       850
# Name: count, dtype: int64

# %% [markdown]
# By Analysing all charts i got these Insights-
#
# 1. SeniorCitizen are more likely to churn
# 2. People With no partners are more likely to churn
# 3. monthly contracts customer are more likely to churn
# 4. people who pay via electronic check are more likely to churn
# 5. customers with no depends as likely to churn
# 6. customers with paperless billing are likely to churn
# 7. customers which does'nt have streaming movies are more likely to churn
# 8. customers which does'nt have streaming tv are more likely to churn
# 9. those customers with no tech support are more likely to churn
# 10. customers with no device protection are churning
# 11. customers with no online backup are churning
# 12. people with no online security are more churning
# 13. people with internet service like fibre optics are more no. of churning

# %% [markdown]
# Numerical Analysis

# %% [markdown]
# Converting the target variable 'Churn' into numeric variable i.e. Yes=1,No=0

# %%
new_df.gender.value_counts()
# Out:
# gender
# Male      3549
# Female    3483
# Name: count, dtype: int64

# %%
new_df1_target0=new_df[new_df['Churn'] == 'No']
new_df1_target1=new_df[new_df['Churn'] == 'Yes']

# %%
new_df1_target1.gender.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
pd.crosstab(new_df.PaymentMethod, new_df.Churn)
# Out:
# Churn                         0     1
# PaymentMethod
# Bank transfer (automatic)  1284   258
# Credit card (automatic)    1289   232
# Electronic check           1294  1071
# Mailed check               1296   308

# %%
new_df['Churn'] = np.where(new_df.Churn == 'Yes',1,0)

# %%
new_df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %%
new_df_dummies = pd.get_dummies(new_df)
new_df_dummies.head()
# Out:
#    SeniorCitizen  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0              0           29.85         29.85      0           True
# 1              0           56.95       1889.50      0          False
# 2              0           53.85        108.15      1          False
# 3              0           42.30       1840.75      0          False
# 4              0           70.70        151.65      1           True
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0        False       False         True           True           False  ...
# 1         True        True        False           True           False  ...
# 2         True        True        False           True           False  ...
# 3         True        True        False           True           False  ...
# 4        False        True        False           True           False  ...
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                    False
# ...

# %%
sns.lmplot(data = new_df_dummies, x='MonthlyCharges', y='TotalCharges',fit_reg = True)

# %% [markdown]
# As Total charges increase Monthly chagres are also increasing

# %%
new_df_dummies['MonthlyCharges'].corr(new_df_dummies['TotalCharges'])
# Out:
# np.float64(0.6510648032262025)

# %%
Mth = sns.kdeplot(new_df_dummies.MonthlyCharges[(new_df_dummies['Churn']==1) ],
                 color = 'Red', shade = True)
Mth = sns.kdeplot(new_df_dummies.MonthlyCharges[(new_df_dummies['Churn']==0) ],
                 color = 'Green', shade = True)
Mth.legend(["Churn","No Churn"], loc='upper right')
Mth.set_ylabel('Density')
Mth.set_xlabel('Monthly Charges')
Mth.set_title('Monthly Charges By Churn')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16824\349873739.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Mth = sns.kdeplot(new_df_dummies.MonthlyCharges[(new_df_dummies['Churn']==1) ],
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16824\349873739.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Mth = sns.kdeplot(new_df_dummies.MonthlyCharges[(new_df_dummies['Churn']==0) ],
# Text(0.5, 1.0, 'Monthly Charges By Churn')

# %% [markdown]
# AS per the chart monthly charges increase churn rate also increase

# %%
Mth = sns.kdeplot(new_df_dummies.TotalCharges[(new_df_dummies['Churn']==1) ],
                 color = 'Red', shade = True)
Mth = sns.kdeplot(new_df_dummies.TotalCharges[(new_df_dummies['Churn']==0) ],
                 color = 'Green', shade = True)
Mth.legend(["Churn","No Churn"], loc='upper right')
Mth.set_ylabel('Density')
Mth.set_xlabel('Total Charges')
Mth.set_title('Total Charges By Churn')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16824\809609361.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Mth = sns.kdeplot(new_df_dummies.TotalCharges[(new_df_dummies['Churn']==1) ],
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16824\809609361.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Mth = sns.kdeplot(new_df_dummies.TotalCharges[(new_df_dummies['Churn']==0) ],
# Text(0.5, 1.0, 'Total Charges By Churn')

# %% [markdown]
# *Suprise Insight As higher the churn at lower total charges

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
Mth = sns.kdeplot(df.tenure[(df['Churn']=="No") ],
                 color = 'Red', shade = True)
Mth = sns.kdeplot(df.tenure[(df['Churn']=="Yes") ],
                 color = 'Green', shade = True)
Mth.legend(["NO Churn","Churn"], loc='upper right')
Mth.set_ylabel('Density')
Mth.set_xlabel('Tenure')
Mth.set_title('Churn By Tenure')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16824\4166311160.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Mth = sns.kdeplot(df.tenure[(df['Churn']=="No") ],
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_16824\4166311160.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Mth = sns.kdeplot(df.tenure[(df['Churn']=="Yes") ],
# Text(0.5, 1.0, 'Churn By Tenure')

# %% [markdown]
# Building a coleration of all the predictors with 'Churn'

# %%
plt.figure(figsize = (20,8))
new_df_dummies.corr()['Churn'].sort_values(ascending = False).plot(kind = 'bar')
# Out:
# <Axes: >
